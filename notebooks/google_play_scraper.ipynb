# %% [markdown]
# #### App Detail

# %%
from google_play_scraper import app

result = app(
    'com.nianticlabs.pokemongo',
    lang='en', # defaults to 'en'
    country='us' # defaults to 'us'
)

# %%
print(result)
# Out:
# {'title': 'Pokémon GO', 'description': 'New! Now you can battle other Pokémon GO Trainers online! Try the GO Battle League today!\r\n\r\nJoin Trainers across the globe who are discovering Pokémon as they explore the world around them. Pokémon GO is the global gaming sensation that has been downloaded over 1 billion times and named “Best Mobile Game” by the Game Developers Choice Awards and “Best App of the Year” by TechCrunch.\r\n_______________\r\n\r\nUncover the world of Pokémon: Explore and discover Pokémon wherever you are!\r\n \r\nCatch more Pokémon to complete your Pokédex!\r\n \r\nJourney alongside your Buddy Pokémon to help make your Pokémon stronger and earn rewards!\r\n\r\nCompete in epic Gym battles and...Team up with other Trainers to catch powerful Pokémon during Raid Battles!\r\n \r\nIt’s time to get moving—your real-life adventures await! Let’s GO!\r\n_______________\r\n\r\nNotes: \r\n- This app is free-to-play and offers in-game purchases. It is optimized for smartphones, not tablets.\r\n- Compatible with Android devices that have 2GB RAM or more and have Android Version 6.0–10.0+ installed.\r\n- Compatibility is not guaranteed for devices without GPS capabilities or devices that are connected only to Wi-Fi networks.\r\n- Application may not run on certain devices even if they have compatible OS versions installed.\r\n- It is recommended to play while connected to a network in order to obtain accurate location information.\r\n- Compatibility information may be changed at any time.\r\n- Please visit PokemonGO.com for additional compatibility information. \r\n- Information current as of October 20, 2020.', 'descriptionHTML': 'New! Now you can battle other Pokémon GO Trainers online! Try the GO Battle League today!<br><br>Join Trainers across the globe who are discovering Pokémon as they explore the world around them. Pokémon GO is the global gaming sensation that has been downloaded over 1 billion times and named “Best Mobile Game” by the Game Developers Choice Awards and “Best App of the Year” by TechCrunch.<br>_______________<br><br>Uncover the world of Pokémon: Explore and discover Pokémon wherever you are!<br> <br>Catch more Pokémon to complete your Pokédex!<br> <br>Journey alongside your Buddy Pokémon to help make your Pokémon stronger and earn rewards!<br><br>Compete in epic Gym battles and...Team up with other Trainers to catch powerful Pokémon during Raid Battles!<br> <br>It’s time to get moving—your real-life adventures await! Let’s GO!<br>_______________<br><br>Notes: <br>- This app is free-to-play and offers in-game purchases. It is optimized for smartphones, not tablets.<br>- Compatible with Android devices that have 2GB RAM or more and have Android Version 6.0–10.0+ installed.<br>- Compatibility is not guaranteed for devices without GPS capabilities or devices that are connected only to Wi-Fi networks.<br>- Application may not run on certain devices even if they have compatible OS versions installed.<br>- It is recommended to play while connected to a network in order to obtain accurate location information.<br>- Compatibility information may be changed at any time.<br>- Please visit PokemonGO.com for additional compatibility information. <br>- Information current as of October 20, 2020.', 'summary': 'Discover Pokémon worldwide', 'installs': '100,000,000+', 'minInstalls': 100000000, 'realInstalls': 478408648, 'score': 4.10255, 'ratings': 15487823, 'reviews': 994309, 'histogram': [2091937, 599357, 914544, 1904596, 9977367], 'price': 0, 'free': True, 'currency': 'USD', 'sale': False, 'saleTime': None, 'originalPrice': None, 'saleText': None, 'offersIAP': True, 'inAppProductPrice': '$0.99 - $99.99 per item', 'developer': 'Niantic, Inc.', 'developerId': 'Niantic,+Inc.', 'developerEmail': 'pokemon-go-support@nianticlabs.com', 'developerWebsite': 'http://pokemongo.nianticlabs.com/', 'developerAddress': 'One Ferry Building, Suite 200\nSan Francisco, CA 94111', 'privacyPolicy': 'https://nianticlabs.com/priva ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(result.items())

# %%
df.T
# Out:
#            0                                                  1   \
# 0       title                                        description
# 1  Pokémon GO  New! Now you can battle other Pokémon GO Train...
#
#                                                   2   \
# 0                                    descriptionHTML
# 1  New! Now you can battle other Pokémon GO Train...
#
#                            3             4            5             6   \
# 0                     summary      installs  minInstalls  realInstalls
# 1  Discover Pokémon worldwide  100,000,000+    100000000     478408648
#
#         7         8        9   ...             34                        35  \
# 0    score   ratings  reviews  ...  contentRating  contentRatingDescription
# 1  4.10255  15487823   994309  ...       Everyone     Mild Fantasy Violence
#
#             36           37           38          39       40  \
# 0  adSupported  containsAds     released     updated  version
# 1        False        False  Jul 6, 2016  1695155439  0.283.1
#
#                                                   41  \
# 0                                           comments
# 1  [Overall, it's a great game. However, I wish B...
#
#                           42  \
# 0                      appId
# 1  com.nianticlabs.pokemongo
#
#                                                   43
# 0                                                url
# 1  https://play.google.com/store/apps/details?id=...
#
# [2 rows x 44 columns]

# %%
# Create a DataFrame
df = pd.DataFrame(result.items(), columns=["Key", "Value"])

# %%
df.head()
# Out:
#                Key                                              Value
# 0            title                                         Pokémon GO
# 1      description  New! Now you can battle other Pokémon GO Train...
# 2  descriptionHTML  New! Now you can battle other Pokémon GO Train...
# 3          summary                         Discover Pokémon worldwide
# 4         installs                                       100,000,000+

# %%
# Create a DataFrame from the dictionary
df = pd.DataFrame.from_dict(result, orient='index', columns=['Value'])
df.index.name = 'Key'

# %%
df.T
# Out:
# Key         title                                        description  \
# Value  Pokémon GO  New! Now you can battle other Pokémon GO Train...
#
# Key                                      descriptionHTML  \
# Value  New! Now you can battle other Pokémon GO Train...
#
# Key                       summary      installs minInstalls realInstalls  \
# Value  Discover Pokémon worldwide  100,000,000+   100000000    478408648
#
# Key      score   ratings reviews  ... contentRating contentRatingDescription  \
# Value  4.10255  15487823  994309  ...      Everyone    Mild Fantasy Violence
#
# Key   adSupported containsAds     released     updated  version  \
# Value       False       False  Jul 6, 2016  1695155439  0.283.1
#
# Key                                             comments  \
# Value  [Overall, it's a great game. However, I wish B...
#
# Key                        appId  \
# Value  com.nianticlabs.pokemongo
#
# Key                                                  url
# Value  https://play.google.com/store/apps/details?id=...
#
# [1 rows x 44 columns]

# %% [markdown]
# #### App Reviews

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.whatsapp',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST
    # count=3, # defaults to 100
    # filter_score_with=5, # defaults to None(means all score)
)

# If you pass `continuation_token` as an argument to the reviews function at this point,
# it will crawl the items after 3 review items.

result, _ = reviews(
    'com.fantome.penguinisle',
    continuation_token=continuation_token # defaults to None(load from the beginning)
)

# %%
print(result)
# Out:
# [{'reviewId': 'f76eec81-b78a-4e2a-ac88-16196c77597d', 'userName': 'Rich Grove', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXhHlXndZ-aIrp6wvb43X0DibwJBI3FbwXskHYkfSYr5gCj', 'content': 'The first couple of years thgis game was great fun to play. Sadly the creators have either run out of ideas or server space as nothing of real note is added to the game any more with the same dull features re-hashed every 6 weeks or so. To compund the issues they have issues with glitched adverts that make game progression nigh on impossible and when you put in reports in the hope of getting things fixed they just send you one line e-mails and fix nothing. Would have been 5 stars 2 years ago', 'score': 2, 'thumbsUpCount': 1, 'reviewCreatedVersion': '1.63.0', 'at': datetime.datetime(2023, 9, 15, 16, 52, 37), 'replyContent': 'Hi! We have passed your feedback to our technical team! Your feedback is very important to us and your opinion is the cornerstone of our progress! Thanks again for your feedback!', 'repliedAt': datetime.datetime(2023, 9, 17, 13, 20, 24), 'appVersion': '1.63.0'}, {'reviewId': 'dab45ef7-52c1-46d6-9836-2ddb878b6a71', 'userName': 'Nico Raharja', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUTq353VEXbtMk7Nw2KIjLWvRxwkabnioSr1F_V99tOA0U', 'content': "Very cute and relaxing, but some things doesn't make sense. Why does Log Flume, the 24th habitat, generates less gold than Octopus Ride, the 22nd habitat, with the same upgrade cost? (Both habitats creatures are the same lvl too) And what's the point of giving more quests and research energies when the research lvl's stuck at 31?", 'score': 5, 'thumbsUpCount': 2, 'reviewCreatedVersion': '1.62.1', 'at': datetime.datetime(2023, 8, 18, 5, 24, 41), 'replyContent': None, 'repliedAt': None, 'appVersion': '1.62.1'}, {'reviewId': 'ae037fd3-ff0e-43dc-97e5-4df56631e515', 'userName': 'joanne s.g.', 'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKqcmdCrhfYuj8pY_073clJRGfxGHZCx9j8yW2Vhn8B=mo', 'content': "Penguin Isle is awesome!All the different type of penguins including the special penguins are so very cute!I really enjoy watching how they interact with the items you place in their habitats and with each other.The free diamonds and rewards for watching short ads are also great!It's exciting as you level up,unlock new penguins and habitats,and receive new items to build.", 'score': 5, 'thumbsUpCount': 1, 'reviewCreatedVersion': '1.62.0', 'at': datetime.datetime(2023, 8, 2, 20, 41, 35), 'replyContent': None, 'repliedAt': None, 'appVersion': '1.62.0'}, {'reviewId': '8a81326a-a2d0-4ce8-bd44-887205665ac5', 'userName': 'Gretchen', 'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLsG4gMomJrdhEdP5pwHQJAq2dj7qJRRUi2vxjNua3xDdI=mo', 'content': "I've had this game since before the first anniversary and they're now having the fourth anniversary! It's a very cute game and the updates are actual improvements to gameplay instead of only bug fixes like other apps. I love all the themed penguins, holiday events, the mini game, and island expansions.", 'score': 5, 'thumbsUpCount': 2, 'reviewCreatedVersion': '1.62.2', 'at': datetime.datetime(2023, 8, 30, 9, 33, 38), 'replyContent': None, 'repliedAt': None, 'appVersion': '1.62.2'}, {'reviewId': '43717414-48eb-476b-bd9a-7454fe9608c6', 'userName': 'Hongyok Fungmongkolsathian', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUHUdUu83H7ZheyQ7lnDO0FvAhYL-UfHSatn_EHhD0XZg', 'content': "This idle game in my view is amazing! It just needs one change I suggest. Can you have the camera rotate up and down and left and right? Because i can't rotate the screen when I'm not building, taking a photo etc.", 'score': 4, 'thumbsUpCount': 0, 'reviewCreatedVersion': '1.62.1', 'at': datetime.datetime(2023, 8, 12, 11, 30, 26), 'replyContent': None, 'repliedAt': None, 'appVersion': '1.62.1'}, {'reviewId': '8f93e833-702a-4f56-9296-25b61cf00d82', 'userName': 'Miriam Ruiz', 'userImage': 'https://play-lh.googleusercontent. ...

# %%
# Create a DataFrame from the dictionary
df = pd.DataFrame(result)

# %%
df
# Out:
#                                 reviewId                    userName  \
# 0   f76eec81-b78a-4e2a-ac88-16196c77597d                  Rich Grove
# 1   dab45ef7-52c1-46d6-9836-2ddb878b6a71                Nico Raharja
# 2   ae037fd3-ff0e-43dc-97e5-4df56631e515                 joanne s.g.
# 3   8a81326a-a2d0-4ce8-bd44-887205665ac5                    Gretchen
# 4   43717414-48eb-476b-bd9a-7454fe9608c6  Hongyok Fungmongkolsathian
# ..                                   ...                         ...
# 95  282d81f2-41f1-44b2-9b28-bb1dc2833d42            Flavio Hernandez
# 96  9fdfb515-71aa-478e-97d3-b9c46ce8b00f               A Google user
# 97  bd38df9c-8b6a-4f09-9cbd-664198110111              Useless Artist
# 98  2f664900-a34c-452b-a2cc-7ff05c27b689               A Google user
# 99  cb48a7bd-4f79-4094-aa82-6e9111445777               A Google user
#
#                                             userImage  \
# 0   https://play-lh.googleusercontent.com/a-/ALV-U...
# 1   https://play-lh.googleusercontent.com/a-/ALV-U...
# 2   https://play-lh.googleusercontent.com/a/ACg8oc...
# 3   https://play-lh.googleusercontent.com/a/ACg8oc...
# 4   https://play-lh.googleusercontent.com/a-/ALV-U...
# ..                                                ...
# 95  https://play-lh.googleusercontent.com/a-/ALV-U...
# 96  https://play-lh.googleusercontent.com/EGemoI2N...
# 97  https://play-lh.googleusercontent.com/a-/ALV-U...
# 98  https://play-lh.googleusercontent.com/EGemoI2N...
# 99  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                               content  score  thumbsUpCount  \
# 0   The first couple of years thgis game was great...      2              1
# 1   Very cute and relaxing, but some things doesn'...      5              2
# 2   Penguin Isle is awesome!All the different type...      5              1
# 3   I've had this game since before the first anni...      5              2
# 4   This idle game in my view is amazing! It just ...      4              0
# ..                                                ...    ...            ...
# 95  I love this game. Great visuals and overall cu...      3             33
# 96  amazing game, it would be even more relaxing i...      5              7
# 97  This game really helped me with my anxiety, it...      5             30
# 98  I'm impressed. This game is different from any...      5             69
# 99  Absolutely love the game. The melody is gorgeo...      4            133
#
#    reviewCreatedVersion                  at  \
# 0                1.63.0 2023-09-15 16:52:37
# 1                1.62.1 2023-08-18 05:24:41
# 2                1.62.0 2023-08-02 20:41:35
# 3                1.62.2 2023-08-30 09:33:38
# 4                1.62.1 2023-08-12 11:30:26
# ..                  ...                 ...
# 95               1.25.2 2020-09-14 22:31:22
# 96                 1.12 2020-01-13 13:23:30
# 97               1.47.1 2022-06-13 02:08:30
# 98                 1.14 2020-02-10 00:09:05
# 99                 1.07 2019-11-09 02:01:29
#
#                                          replyContent           repliedAt  \
# 0   Hi! We have passed your feedback to our techni... 2023-09-17 13:20:24
# 1                                                None                 NaT
# 2                                                None                 NaT
# 3                                                None                 NaT
# 4                                                None                 NaT
# ..                                                ...                 ...
# 95  Hello,Save or share the game, iOS through Game... 2020-09-14 09:11:29
# 96  Hi,We will gradually improve the various syste... 2020-01-13 13:29:02
# 97                                               None                 NaT
# 98                                               None                 NaT
# 99  We will gradually improve the various systems ... 2019-11-09 18:33:45
#
#    appVersion
# 0      1.63.0
# 1      1.62.1
# 2      1.62.0
# 3      1.62.2
# 4      1.62.1
# ..        ...
# 95     1.25.2
# 96       1.12
# 97     1.47.1
# 98       1.14
# 99       1.07
#
# [100 rows x 11 columns]

# %%
df.shape
# Out:
# (3, 11)
